# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 611

# %%
# Import the requests library.
import requests

# Import the API key.
from Config import weather_api_keys

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_keys
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c94c2de414882947206b4f0a7f4989c8

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | akdepe
# Processing Record 3 of Set 1 | saint-philippe
# Processing Record 4 of Set 1 | galle
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | cabo san lucas
# Processing Record 8 of Set 1 | tasiilaq
# Processing Record 9 of Set 1 | northam
# Processing Record 10 of Set 1 | bay roberts
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 1 | cidreira
# Processing Record 15 of Set 1 | inhambane
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | egvekinot
# Processing Record 19 of Set 1 | sorland
# Processing Record 20 of Set 1 | nemuro
# Processing Record 21 of Set 1 | kamenka
# Processing Record 22 of Set 1 | butaritari
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | pangnirtung
# Processing Record 25 of Set 1 | gondanglegi
# Processing Record 26 of Set 1 | isangel
# Processing Record 27 of Set 1 | torbay
# Processing Record 28 of Set 1 | eichstatt
# Processing Record 29 of Set 1 | mananjary
# Processing Record 30 of Set 1 | san quintin
# Processing Record 31 of Set 1 | sterling
# Processing Record 32 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 1 | ayagoz
# Processing Record 34 of Set 1 | vao
# Processing Record 35 of Set 1 | znamenskoye
# Processing Record 36 of Set 1 | coahuayana
# Processing Record 37 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 38 of Set 1 | talnakh
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | viedma
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 1 | coihaique
# Processing Record 47 of Set 1 | east london
# Processing Record 48 of Set 1 | saldanha
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | esperance
# Processing Record 1 of Set 2 | charters towers
# Processing Record 2 of Set 2 | belle fourche
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | saint-francois
# Processing Record 6 of Set 2 | ilinskiy
# Processing Record 7 of Set 2 | lompoc
# Processing Record 8 of Set 2 | cherskiy
# Processing Record 9 of Set 2 | mahibadhoo
# Processing Record 10 of Set 2 | narsaq
# Processing Record 11 of Set 2 | sabang
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | paamiut
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | ilhabela
# Processing Record 16 of Set 2 | lamu
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 2 | buariki
# City not found. Skipping...
# Processing Record 20 of Set 2 | milkovo
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | porto santo
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | lavrentiya
# Processing Record 25 of Set 2 | kodiak
# Processing Record 26 of Set 2 | tahe
# Processing Record 27 of Set 2 | muravlenko
# Processing Record 28 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 29 of Set 2 | albany
# Processing Record 30 of Set 2 | chuy
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | pochutla
# Processing Record 33 of Set 2 | ushuaia
# Processing Record 34 of Set 2 | georgetown
# Processing Record 35 of Set 2 | port shepstone
# Processing Record 36 of Set 2 | guerrero negro
# Processing Record 37 of Set 2 | villazon
# Processing Record 38 of Set 2 | falam
# Processing Record 39 of Set 2 | carutapera
# Processing Record 40 of Set 2 | port elizabeth
# Processing Record 41 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 2 | sitia
# Processing Record 43 of Set 2 | beloha
# Processing Record 44 of Set 2 | bethel
# Processing Record 45 of Set 2 | muros
# Processing Record 46 of Set 2 | saint george
# Processing Record 47 of Set 2 | kurilsk
# Processing Record 48 of Set 2 | nikolskoye
# Processing Record 49 of Set 2 | koboko
# Processing Record 50 of Set 2 | atyuryevo
# City not found. Skipping...
# Processing Record 1 of Set 3 | killybegs
# Processing Record 2 of Set 3 | qaanaaq
# Processing Record 3 of Set 3 | my tho
# Processing Record 4 of Set 3 | avarua
# Processing Record 5 of Set 3 | biak
# Processing Record 6 of Set 3 | chapadinha
# Processing Record 7 of Set 3 | lagoa
# Processing Record 8 of Set 3 | norman wells
# Processing Record 9 of Set 3 | dijkot
# Processing Record 10 of Set 3 | chumikan
# Processing Record 11 of Set 3 | chateau-gontier
# Processing Record 12 of Set 3 | vyartsilya
# Processing Record 13 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 14 of Set 3 | namibe
# Processing Record 15 of Set 3 | mbandaka
# Processing Record 16 of Set 3 | karratha
# Processing Record 17 of Set 3 | buta
# Processing Record 18 of Set 3 | daru
# Processing Record 19 of Set 3 | mount isa
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | tiksi
# Processing Record 22 of Set 3 | dalvik
# Processing Record 23 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 3 | hamilton
# Processing Record 25 of Set 3 | lebu
# Processing Record 26 of Set 3 | sitka
# Processing Record 27 of Set 3 | namatanai
# Processing Record 28 of Set 3 | montero
# Processing Record 29 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 3 | chokurdakh
# Processing Record 31 of Set 3 | praia
# Processing Record 32 of Set 3 | nishihara
# Processing Record 33 of Set 3 | mar del plata
# Processing Record 34 of Set 3 | marzuq
# Processing Record 35 of Set 3 | yar-sale
# Processing Record 36 of Set 3 | bambous virieux
# Processing Record 37 of Set 3 | khatanga
# Processing Record 38 of Set 3 | angoche
# Processing Record 39 of Set 3 | laguna
# Processing Record 40 of Set 3 | punuare
# Processing Record 41 of Set 3 | padang
# Processing Record 42 of Set 3 | zhangjiakou
# Processing Record 43 of Set 3 | bordighera
# Processing Record 44 of Set 3 | salalah
# Processing Record 45 of Set 3 | grindavik
# Processing Record 46 of Set 3 | honningsvag
# Processing Record 47 of Set 3 | balta doamnei
# Processing Record 48 of Set 3 | rognan
# Processing Record 49 of Set 3 | camas
# Processing Record 50 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 4 | kruisfontein
# Processing Record 2 of Set 4 | verkhoyansk
# Processing Record 3 of Set 4 | ribeira grande
# Processing Record 4 of Set 4 | barrow
# Processing Record 5 of Set 4 | nouadhibou
# Processing Record 6 of Set 4 | wageningen
# Processing Record 7 of Set 4 | porirua
# Processing Record 8 of Set 4 | chapais
# Processing Record 9 of Set 4 | chitapur
# Processing Record 10 of Set 4 | roma
# Processing Record 11 of Set 4 | samarai
# Processing Record 12 of Set 4 | victoria
# Processing Record 13 of Set 4 | adrar
# Processing Record 14 of Set 4 | luanda
# Processing Record 15 of Set 4 | ponta do sol
# Processing Record 16 of Set 4 | sao filipe
# Processing Record 17 of Set 4 | leningradskiy
# Processing Record 18 of Set 4 | puerto carreno
# Processing Record 19 of Set 4 | yumen
# Processing Record 20 of Set 4 | champua
# Processing Record 21 of Set 4 | lorengau
# Processing Record 22 of Set 4 | vershino-darasunskiy
# Processing Record 23 of Set 4 | okhotsk
# Processing Record 24 of Set 4 | chlumec
# Processing Record 25 of Set 4 | hofn
# Processing Record 26 of Set 4 | kahului
# Processing Record 27 of Set 4 | mus
# Processing Record 28 of Set 4 | fuengirola
# Processing Record 29 of Set 4 | dudinka
# Processing Record 30 of Set 4 | le moule
# Processing Record 31 of Set 4 | souillac
# Processing Record 32 of Set 4 | stonewall
# Processing Record 33 of Set 4 | caravelas
# Processing Record 34 of Set 4 | luang prabang
# Processing Record 35 of Set 4 | college
# Processing Record 36 of Set 4 | duku
# Processing Record 37 of Set 4 | doba
# Processing Record 38 of Set 4 | contramaestre
# Processing Record 39 of Set 4 | half moon bay
# Processing Record 40 of Set 4 | severo-kurilsk
# Processing Record 41 of Set 4 | aklavik
# Processing Record 42 of Set 4 | loikaw
# Processing Record 43 of Set 4 | hilo
# Processing Record 44 of Set 4 | new norfolk
# Processing Record 45 of Set 4 | jiuquan
# Processing Record 46 of Set 4 | kapaa
# Processing Record 47 of Set 4 | constitucion
# Processing Record 48 of Set 4 | morondava
# Processing Record 49 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 4 | sharjah
# Processing Record 1 of Set 5 | geraldton
# Processing Record 2 of Set 5 | dunedin
# Processing Record 3 of Set 5 | ruteng
# Processing Record 4 of Set 5 | mount gambier
# Processing Record 5 of Set 5 | vestmannaeyjar
# Processing Record 6 of Set 5 | maceio
# Processing Record 7 of Set 5 | port hardy
# Processing Record 8 of Set 5 | alofi
# Processing Record 9 of Set 5 | clyde river
# Processing Record 10 of Set 5 | muisne
# Processing Record 11 of Set 5 | port hueneme
# Processing Record 12 of Set 5 | tarata
# Processing Record 13 of Set 5 | port-gentil
# Processing Record 14 of Set 5 | douentza
# Processing Record 15 of Set 5 | sucua
# Processing Record 16 of Set 5 | zhigansk
# Processing Record 17 of Set 5 | cuenca
# Processing Record 18 of Set 5 | mersing
# Processing Record 19 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 5 | longyearbyen
# Processing Record 21 of Set 5 | portobelo
# Processing Record 22 of Set 5 | vila franca do campo
# Processing Record 23 of Set 5 | ostrovnoy
# Processing Record 24 of Set 5 | luganville
# Processing Record 25 of Set 5 | saint-pierre
# Processing Record 26 of Set 5 | santa cruz
# Processing Record 27 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 5 | klaksvik
# Processing Record 29 of Set 5 | houma
# Processing Record 30 of Set 5 | sao felix do xingu
# Processing Record 31 of Set 5 | palmer
# Processing Record 32 of Set 5 | gobo
# Processing Record 33 of Set 5 | agulu
# Processing Record 34 of Set 5 | san patricio
# Processing Record 35 of Set 5 | ambon
# Processing Record 36 of Set 5 | morehead
# Processing Record 37 of Set 5 | marsh harbour
# Processing Record 38 of Set 5 | sakskobing
# Processing Record 39 of Set 5 | mecca
# Processing Record 40 of Set 5 | pisco
# Processing Record 41 of Set 5 | najran
# Processing Record 42 of Set 5 | todos santos
# Processing Record 43 of Set 5 | vilhena
# Processing Record 44 of Set 5 | ancud
# Processing Record 45 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 5 | opuwo
# Processing Record 47 of Set 5 | sao joao da barra
# Processing Record 48 of Set 5 | ibipora
# Processing Record 49 of Set 5 | thompson
# Processing Record 50 of Set 5 | provideniya
# Processing Record 1 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 6 | mamakan
# Processing Record 3 of Set 6 | veraval
# Processing Record 4 of Set 6 | bathsheba
# Processing Record 5 of Set 6 | san jose
# Processing Record 6 of Set 6 | laguna de duero
# Processing Record 7 of Set 6 | vredefort
# Processing Record 8 of Set 6 | sao miguel do araguaia
# Processing Record 9 of Set 6 | husavik
# Processing Record 10 of Set 6 | ahipara
# Processing Record 11 of Set 6 | remanso
# Processing Record 12 of Set 6 | hualmay
# Processing Record 13 of Set 6 | port keats
# Processing Record 14 of Set 6 | baghdad
# Processing Record 15 of Set 6 | airai
# Processing Record 16 of Set 6 | sakakah
# Processing Record 17 of Set 6 | grand gaube
# Processing Record 18 of Set 6 | atasu
# Processing Record 19 of Set 6 | broome
# Processing Record 20 of Set 6 | petauke
# Processing Record 21 of Set 6 | arcachon
# Processing Record 22 of Set 6 | yamada
# Processing Record 23 of Set 6 | port lincoln
# Processing Record 24 of Set 6 | valparaiso
# Processing Record 25 of Set 6 | bilma
# Processing Record 26 of Set 6 | evensk
# Processing Record 27 of Set 6 | salina
# Processing Record 28 of Set 6 | comodoro rivadavia
# Processing Record 29 of Set 6 | guanare
# Processing Record 30 of Set 6 | huarmey
# Processing Record 31 of Set 6 | tutoia
# Processing Record 32 of Set 6 | wenatchee
# Processing Record 33 of Set 6 | nadym
# Processing Record 34 of Set 6 | poso
# Processing Record 35 of Set 6 | sola
# Processing Record 36 of Set 6 | carnarvon
# Processing Record 37 of Set 6 | teya
# Processing Record 38 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 39 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 6 | bend
# Processing Record 41 of Set 6 | te anau
# Processing Record 42 of Set 6 | ust-shonosha
# Processing Record 43 of Set 6 | upernavik
# Processing Record 44 of Set 6 | santiago del estero
# Processing Record 45 of Set 6 | gamba
# Processing Record 46 of Set 6 | terney
# Processing Record 47 of Set 6 | tostamaa
# City not found. Skipping...
# Processing Record 48 of Set 6 | kavaratti
# Processing Record 49 of Set 6 | kalabo
# Processing Record 50 of Set 6 | ulladulla
# Processing Record 1 of Set 7 | sur
# Processing Record 2 of Set 7 | lasa
# Processing Record 3 of Set 7 | murmashi
# Processing Record 4 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 7 | leshukonskoye
# Processing Record 6 of Set 7 | mahanje
# Processing Record 7 of Set 7 | boundiali
# Processing Record 8 of Set 7 | majene
# Processing Record 9 of Set 7 | fortuna
# Processing Record 10 of Set 7 | waingapu
# Processing Record 11 of Set 7 | senador guiomard
# Processing Record 12 of Set 7 | faanui
# Processing Record 13 of Set 7 | danielskuil
# Processing Record 14 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 7 | saint-augustin
# Processing Record 16 of Set 7 | dubenskiy
# City not found. Skipping...
# Processing Record 17 of Set 7 | flinders
# Processing Record 18 of Set 7 | akdagmadeni
# Processing Record 19 of Set 7 | santo andre
# Processing Record 20 of Set 7 | kununurra
# Processing Record 21 of Set 7 | yershichi
# Processing Record 22 of Set 7 | dawei
# Processing Record 23 of Set 7 | navolato
# Processing Record 24 of Set 7 | tautira
# Processing Record 25 of Set 7 | tshikapa
# Processing Record 26 of Set 7 | cabedelo
# Processing Record 27 of Set 7 | san policarpo
# Processing Record 28 of Set 7 | la palma
# Processing Record 29 of Set 7 | barmer
# Processing Record 30 of Set 7 | kosh-agach
# Processing Record 31 of Set 7 | great yarmouth
# Processing Record 32 of Set 7 | vitim
# Processing Record 33 of Set 7 | kachikau
# City not found. Skipping...
# Processing Record 34 of Set 7 | petropavlovka
# Processing Record 35 of Set 7 | los llanos de aridane
# Processing Record 36 of Set 7 | korsakovo
# Processing Record 37 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 38 of Set 7 | beneditinos
# Processing Record 39 of Set 7 | floro
# Processing Record 40 of Set 7 | gargzdai
# Processing Record 41 of Set 7 | mindelo
# Processing Record 42 of Set 7 | kalabagh
# Processing Record 43 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 7 | kodinsk
# Processing Record 45 of Set 7 | temozon
# Processing Record 46 of Set 7 | rocha
# Processing Record 47 of Set 7 | galesong
# Processing Record 48 of Set 7 | jacarei
# Processing Record 49 of Set 7 | sechura
# Processing Record 50 of Set 7 | saeby
# Processing Record 1 of Set 8 | kuryk
# Processing Record 2 of Set 8 | biltine
# Processing Record 3 of Set 8 | balykshi
# Processing Record 4 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 8 | chifeng
# Processing Record 6 of Set 8 | camacha
# Processing Record 7 of Set 8 | quatre cocos
# Processing Record 8 of Set 8 | san carlos de bariloche
# Processing Record 9 of Set 8 | sterlitamak
# Processing Record 10 of Set 8 | colon
# Processing Record 11 of Set 8 | san javier
# Processing Record 12 of Set 8 | mezen
# Processing Record 13 of Set 8 | thinadhoo
# Processing Record 14 of Set 8 | konan
# Processing Record 15 of Set 8 | areosa
# Processing Record 16 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 17 of Set 8 | riyadh
# Processing Record 18 of Set 8 | asau
# Processing Record 19 of Set 8 | darhan
# Processing Record 20 of Set 8 | henties bay
# Processing Record 21 of Set 8 | flin flon
# Processing Record 22 of Set 8 | blairmore
# Processing Record 23 of Set 8 | lerwick
# Processing Record 24 of Set 8 | alappuzha
# Processing Record 25 of Set 8 | bilaspur
# Processing Record 26 of Set 8 | chaykovskiy
# Processing Record 27 of Set 8 | hambantota
# Processing Record 28 of Set 8 | teguldet
# Processing Record 29 of Set 8 | komsomolskiy
# Processing Record 30 of Set 8 | el dorado
# Processing Record 31 of Set 8 | nizhniy kuranakh
# Processing Record 32 of Set 8 | tahta
# Processing Record 33 of Set 8 | khakhea
# Processing Record 34 of Set 8 | sochi
# Processing Record 35 of Set 8 | pevek
# Processing Record 36 of Set 8 | avera
# Processing Record 37 of Set 8 | beidao
# Processing Record 38 of Set 8 | bereda
# Processing Record 39 of Set 8 | parakou
# Processing Record 40 of Set 8 | richards bay
# Processing Record 41 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 8 | grand-santi
# Processing Record 43 of Set 8 | kaitangata
# Processing Record 44 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 45 of Set 8 | bengkulu
# Processing Record 46 of Set 8 | serenje
# Processing Record 47 of Set 8 | kyaiklat
# Processing Record 48 of Set 8 | kirakira
# Processing Record 49 of Set 8 | turayf
# Processing Record 50 of Set 8 | forio
# Processing Record 1 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 9 | mogok
# Processing Record 3 of Set 9 | destin
# Processing Record 4 of Set 9 | verkhnyaya inta
# Processing Record 5 of Set 9 | santa adelia
# Processing Record 6 of Set 9 | saskylakh
# Processing Record 7 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 9 | ust-koksa
# Processing Record 9 of Set 9 | otradnoye
# Processing Record 10 of Set 9 | sorong
# Processing Record 11 of Set 9 | cockburn town
# Processing Record 12 of Set 9 | makubetsu
# Processing Record 13 of Set 9 | luderitz
# Processing Record 14 of Set 9 | whyalla
# Processing Record 15 of Set 9 | tagusao
# Processing Record 16 of Set 9 | mandalgovi
# Processing Record 17 of Set 9 | humaita
# Processing Record 18 of Set 9 | konstantinovka
# Processing Record 19 of Set 9 | sao jose da coroa grande
# Processing Record 20 of Set 9 | kothi
# Processing Record 21 of Set 9 | tortoli
# Processing Record 22 of Set 9 | les escoumins
# Processing Record 23 of Set 9 | vestmanna
# Processing Record 24 of Set 9 | natal
# Processing Record 25 of Set 9 | ji-parana
# City not found. Skipping...
# Processing Record 26 of Set 9 | kavieng
# Processing Record 27 of Set 9 | batagay
# Processing Record 28 of Set 9 | scottsboro
# Processing Record 29 of Set 9 | khash
# Processing Record 30 of Set 9 | brae
# Processing Record 31 of Set 9 | beringovskiy
# Processing Record 32 of Set 9 | kampot
# Processing Record 33 of Set 9 | thessalon
# Processing Record 34 of Set 9 | makakilo city
# Processing Record 35 of Set 9 | ewa beach
# Processing Record 36 of Set 9 | alice springs
# Processing Record 37 of Set 9 | maragogi
# Processing Record 38 of Set 9 | alyangula
# Processing Record 39 of Set 9 | trinidad
# Processing Record 40 of Set 9 | tonala
# Processing Record 41 of Set 9 | mackenzie
# Processing Record 42 of Set 9 | mogadishu
# Processing Record 43 of Set 9 | cranbrook
# Processing Record 44 of Set 9 | scarborough
# Processing Record 45 of Set 9 | zhenjiang
# Processing Record 46 of Set 9 | birjand
# Processing Record 47 of Set 9 | mayumba
# Processing Record 48 of Set 9 | camopi
# Processing Record 49 of Set 9 | gat
# Processing Record 50 of Set 9 | samana
# Processing Record 1 of Set 10 | zhezkazgan
# Processing Record 2 of Set 10 | vanino
# Processing Record 3 of Set 10 | ola
# Processing Record 4 of Set 10 | jinchengjiang
# City not found. Skipping...
# Processing Record 5 of Set 10 | colares
# Processing Record 6 of Set 10 | ponta delgada
# Processing Record 7 of Set 10 | kupang
# Processing Record 8 of Set 10 | tadine
# Processing Record 9 of Set 10 | waw
# Processing Record 10 of Set 10 | omboue
# Processing Record 11 of Set 10 | adra
# Processing Record 12 of Set 10 | mandleshwar
# Processing Record 13 of Set 10 | deputatskiy
# Processing Record 14 of Set 10 | leh
# Processing Record 15 of Set 10 | iqaluit
# Processing Record 16 of Set 10 | aksarka
# Processing Record 17 of Set 10 | mao
# Processing Record 18 of Set 10 | meulaboh
# Processing Record 19 of Set 10 | tokur
# Processing Record 20 of Set 10 | bovolone
# Processing Record 21 of Set 10 | batticaloa
# Processing Record 22 of Set 10 | durban
# Processing Record 23 of Set 10 | belyy yar
# Processing Record 24 of Set 10 | harper
# Processing Record 25 of Set 10 | walvis bay
# Processing Record 26 of Set 10 | thyboron
# Processing Record 27 of Set 10 | denpasar
# Processing Record 28 of Set 10 | rio claro
# Processing Record 29 of Set 10 | east stroudsburg
# Processing Record 30 of Set 10 | azare
# Processing Record 31 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 32 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 10 | cedar city
# Processing Record 34 of Set 10 | balkhash
# Processing Record 35 of Set 10 | rheinbach
# Processing Record 36 of Set 10 | homer
# Processing Record 37 of Set 10 | magadan
# Processing Record 38 of Set 10 | moerai
# Processing Record 39 of Set 10 | toccoa
# Processing Record 40 of Set 10 | svetlogorsk
# Processing Record 41 of Set 10 | naze
# Processing Record 42 of Set 10 | taburao
# City not found. Skipping...
# Processing Record 43 of Set 10 | chatellerault
# Processing Record 44 of Set 10 | saint anthony
# Processing Record 45 of Set 10 | saltpond
# Processing Record 46 of Set 10 | minatitlan
# Processing Record 47 of Set 10 | nogliki
# Processing Record 48 of Set 10 | chyhyryn
# Processing Record 49 of Set 10 | tual
# Processing Record 50 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 1 of Set 11 | burica
# City not found. Skipping...
# Processing Record 2 of Set 11 | abu samrah
# Processing Record 3 of Set 11 | ahuimanu
# Processing Record 4 of Set 11 | washington
# Processing Record 5 of Set 11 | columbus
# Processing Record 6 of Set 11 | marsa matruh
# Processing Record 7 of Set 11 | sorsk
# Processing Record 8 of Set 11 | olafsvik
# Processing Record 9 of Set 11 | nyuksenitsa
# Processing Record 10 of Set 11 | cayenne
# Processing Record 11 of Set 11 | torres
# Processing Record 12 of Set 11 | sargatskoye
# Processing Record 13 of Set 11 | boddam
# Processing Record 14 of Set 11 | taltal
# Processing Record 15 of Set 11 | grong
# Processing Record 16 of Set 11 | pangkalanbuun
# Processing Record 17 of Set 11 | nanortalik
# Processing Record 18 of Set 11 | khandyga
# Processing Record 19 of Set 11 | stornoway
# Processing Record 20 of Set 11 | palu
# Processing Record 21 of Set 11 | codrington
# Processing Record 22 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 23 of Set 11 | libreville
# Processing Record 24 of Set 11 | nakambala
# Processing Record 25 of Set 11 | tuatapere
# Processing Record 26 of Set 11 | talcahuano
# Processing Record 27 of Set 11 | krk
# Processing Record 28 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 29 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 30 of Set 11 | mopipi
# Processing Record 31 of Set 11 | fairbanks
# Processing Record 32 of Set 11 | green valley
# Processing Record 33 of Set 11 | mantua
# Processing Record 34 of Set 11 | bama
# Processing Record 35 of Set 11 | jalu
# Processing Record 36 of Set 11 | parabel
# Processing Record 37 of Set 11 | kilindoni
# Processing Record 38 of Set 11 | boa vista
# Processing Record 39 of Set 11 | bubaque
# Processing Record 40 of Set 11 | hoorn
# Processing Record 41 of Set 11 | raymond
# Processing Record 42 of Set 11 | ilulissat
# Processing Record 43 of Set 11 | angat
# Processing Record 44 of Set 11 | kloulklubed
# Processing Record 45 of Set 11 | lensk
# Processing Record 46 of Set 11 | naliya
# Processing Record 47 of Set 11 | turkmenabat
# Processing Record 48 of Set 11 | pafos
# Processing Record 49 of Set 11 | orje
# Processing Record 50 of Set 11 | miri
# Processing Record 1 of Set 12 | nurota
# Processing Record 2 of Set 12 | baherden
# Processing Record 3 of Set 12 | margate
# Processing Record 4 of Set 12 | wajir
# Processing Record 5 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 12 | gazojak
# Processing Record 7 of Set 12 | saint-paul
# Processing Record 8 of Set 12 | canala
# Processing Record 9 of Set 12 | port augusta
# Processing Record 10 of Set 12 | muroto
# Processing Record 11 of Set 12 | isiro
# Processing Record 12 of Set 12 | voh
# Processing Record 13 of Set 12 | mufulira
# Processing Record 14 of Set 12 | lukovetskiy
# Processing Record 15 of Set 12 | paris
# Processing Record 16 of Set 12 | ikalamavony
# Processing Record 17 of Set 12 | bilibino
# Processing Record 18 of Set 12 | praia da vitoria
# Processing Record 19 of Set 12 | ambilobe
# Processing Record 20 of Set 12 | litchfield
# Processing Record 21 of Set 12 | lachi
# Processing Record 22 of Set 12 | eenhana
# Processing Record 23 of Set 12 | vardo
# Processing Record 24 of Set 12 | vila
# Processing Record 25 of Set 12 | nivala
# Processing Record 26 of Set 12 | nago
# Processing Record 27 of Set 12 | port macquarie
# Processing Record 28 of Set 12 | ixtapa
# Processing Record 29 of Set 12 | tecuala
# Processing Record 30 of Set 12 | kattivakkam
# Processing Record 31 of Set 12 | pahrump
# Processing Record 32 of Set 12 | canatlan
# Processing Record 33 of Set 12 | ashland
# Processing Record 34 of Set 12 | havre-saint-pierre
# Processing Record 35 of Set 12 | cap malheureux
# Processing Record 36 of Set 12 | svetlyy
# Processing Record 37 of Set 12 | yaroslavl
# Processing Record 38 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 12 | adre
# Processing Record 40 of Set 12 | jesus de otoro
# Processing Record 41 of Set 12 | port blair
# Processing Record 42 of Set 12 | matara
# Processing Record 43 of Set 12 | zacatepec
# Processing Record 44 of Set 12 | puerto leguizamo
# Processing Record 45 of Set 12 | uromi
# Processing Record 46 of Set 12 | ilave
# Processing Record 47 of Set 12 | nam tha
# City not found. Skipping...
# Processing Record 48 of Set 12 | kakonko
# Processing Record 49 of Set 12 | tome-acu
# City not found. Skipping...
# Processing Record 50 of Set 12 | mokhsogollokh
# Processing Record 1 of Set 13 | tigre
# Processing Record 2 of Set 13 | akureyri
# Processing Record 3 of Set 13 | umm kaddadah
# Processing Record 4 of Set 13 | newport
# Processing Record 5 of Set 13 | salinas
# Processing Record 6 of Set 13 | san miguel
# Processing Record 7 of Set 13 | hovd
# Processing Record 8 of Set 13 | aginskoye
# Processing Record 9 of Set 13 | gbarnga
# Processing Record 10 of Set 13 | bilaua
# City not found. Skipping...
# Processing Record 11 of Set 13 | bargal
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Hermanus -34.42   19.23     61.00        81          86       12.95
# 1          Akdepe  42.06   59.38     53.60        41           0        9.17
# 2  Saint-Philippe -21.36   55.77     69.80        73           0        5.82
# 3           Galle   6.04   80.22     78.85        85         100        7.52
# 4      Bredasdorp -34.53   20.04     62.60        82         100        5.82
# 5     Tuktoyaktuk  69.45 -133.04     23.00        92          90       26.40
# 6  Cabo San Lucas  22.89 -109.91     93.20        49          20        5.82
# 7        Tasiilaq  65.61  -37.64     30.20        86         100        6.42
# 8         Northam  51.03   -4.22     50.00        90           0        5.99
# 9     Bay Roberts  47.60  -53.26     44.01        88          86        5.99
#
#   Country      Description
# 0      ZA  overcast clouds
# 1      TM        clear sky
# 2      RE        clear sky
# 3      LK  overcast clouds
# 4      ZA  overcast clouds
# 5      CA       light snow
# 6      MX       few clouds
# 7      GL  overcast clouds
# 8      GB       light rain
# 9      CA  overcast clouds

# %%
new_column_order = ["City", "Country","Lat","Lng","Max Temp", "Humidity","Cloudiness","Wind Speed","Description"]
city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
